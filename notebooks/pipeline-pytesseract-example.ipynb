# %%
import mmcv
import src.features.build_features as pp
from src.visualization.visualize import *

# %%
url0 = '../data/raw/example.jpg'
image0 = mmcv.imread(url0)

def preprocessing(image):
    image = mmcv.bgr2gray(image)
    image = pp.threshold(image, thresh=120)
    image = mmcv.gray2rgb(image)

    return image

image0 = preprocessing(image0)

show(image0)

# %%
from src.models.ocr import OCRModelFactory

tt_model = OCRModelFactory.create("pytesseract")

# %%
tt_model(image0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pytesseract\pytesseract.py:388, in get_tesseract_version()
#     387 try:
# --> 388     output = subprocess.check_output(
#     389         [tesseract_cmd, '--version'],
#     390         stderr=subprocess.STDOUT,
#     391         env=environ,
#     392         stdin=subprocess.DEVNULL,
#     393     )
#     394 except OSError:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\subprocess.py:424, in check_output(timeout, *popenargs, **kwargs)
#     422     kwargs['input'] = empty
# --> 424 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     425            **kwargs).stdout
#
# File ~\AppData\Local\Programs\Python\Python39\lib\subprocess.py:505, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
# ...

# %%
# !tesseract --version
# Out:
# "tesseract" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.

# %%
# if you are not in IDE
import os

project_root = "/mnt/c/Users/dimka/PycharmProjects/TatneftIT_OCR"
os.chdir(project_root)

# %%
import mmcv
import src.features.build_features as pp
from src.visualization.visualize import *

# %%
url0 = r'notebooks/data/09.03.17 1200.jpg'
image0 = mmcv.imread(url0)

def preprocessing(image):
    image = pp.cut_image(image)
    image = mmcv.bgr2gray(image)
    image = pp.adaptive_threshold(image, block_size=501, c_var=55)
    image = mmcv.gray2rgb(image)

    return image

image0 = preprocessing(image0)

show(image0)

# %%
from src.models.ocr import OCRModelFactory

model = OCRModelFactory.create("pytesseract")
# Out:
# Using CPU. Note: This module is much faster with a GPU.

# %%
outputs = model([image0])

# %%
result2show(image0, outputs[0])

# %%
' '.join(outputs[0]['rec_texts'])
# Out:
# 'ООО "ТНГ-АлГИС" КСА ООО "ТНГ-Групп" Заказчик ООО "Гольфстрим" Точк Площадь Сармановская Скважина 11804д РД Категория ~ ОПРЕДЕЛЕНИЕ ПРОФИЛЯ ПРИЕМИСТОСТИ 4 ЗАБОЯ МЕТОДАМИ: 8 ТЕРМОМЕТРИИ; МАНОМЕТРИИ; РГД; СТИ; ГК; ЛОКАЦИИ МУФТ: Дата исследования 09.03,201  Интервал исследования 1590-1746 ЛМ Дата обработки 10.03.201- Масштаб :200 Конструкция скважины Сведения об аппаратуне Забой 746.0 Тип прибора;  : КСА-Т12 {:722 Диаметр Скв_ ПО долоту #м 216.0 Метод ГЙС ТМ вм  @.&& ;Щ СС< ГК Диаметр колонны; мМ 146.0 102 Ед изм 9/а(С ащ #/щп {щ:п ш Башмак колонны; м 1746,0 7582,4-1745,4 Ск-ть заПисимч 400 400 Диаметр кондуктора; М# 245.0 Счетчик ГК: Па) 16х40 Мертвая зона локатора муфт 1.30 Башмак кондуктора; 284.0 Наземное оборусование Диаметр НКТ Мм 73.0 Каротажная станция Кабель КГ-3*0.75-60.150  Длина(м}:4о00 Башкак НКГ, м 1685 Цена метки Поспедней Контрольной: Состояние скв  до замера простаивапа интераал работ интервал Закачка от агрегата; атм 105 перфорациим ло СТИ; м мощн:м мЗ/сут 1734,40 1738,40 1736.0-1737.8 1,8 152 100 МН Условныо обозначения Запись провёл (&: нач партии) 8981 Хайротвннов ТмО, ВМО- контр; замер термометром манометром Примечание; СТИ Т*Р 1, ВМР)1- после закачки 7,5 мЗ воды за 85 мин Глубины приведены по замеру ГК; НКт от 25.10.2012 г ТМР)2; ВМР)2 после закачки 7,5 мЗ воды за 85 мин ВЛ Заключение; Закачиваемая вода поглощается интервалом перфорации Тм [Затрубная циркуляция жидкости вниз данным исследованием не выявлена Кривые термометрии зумпфе скважины искажены влиянием грязи учётом разогрева по СТИ на забое зумпф герметичен. Рез: шение герметичности Э/колонны ниже башмака НКТ данным исследованием не выявлено: Общая приемистость скважины 152 мЗ/сут Забой по локатору муфт 1744, м + 1,3 м \'м.3 Старший геолог: Давлетшина А. С: Интерпретатор: О@ЦНизаева эд раб. Нарут'

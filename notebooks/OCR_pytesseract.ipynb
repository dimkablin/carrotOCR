# %%
# if you are not in IDE
import os

project_root = "/mnt/c/Users/dimka/PycharmProjects/TatneftIT_OCR"
os.chdir(project_root)

# %%
import mmcv
import src.features.build_features as pp
from src.visualization.visualize import *

# %%
url0 = r'data/raw/18.08.04 200.jpg'
image0 = mmcv.imread(url0)

def preprocessing(image):
    image = pp.cut_image(image)
    image = mmcv.bgr2gray(image)
    image = pp.adaptive_threshold(image, block_size=501, c_var=15)
    image = mmcv.gray2rgb(image)

    return image

image0 = preprocessing(image0)

show(image0)

# %%
from src.models.ocr import OCRModelFactory

model = OCRModelFactory.create("pytesseract")

# %%
outputs = model([image0])

# %%
result2show(image0, outputs[0])

# %%
' '.join(outputs[0]['rec_texts'])
# Out:
# '\' ОАО "ТАТНЕФТЕГЕОФИЗИКА" | АЛЬМЕТЬЕВСКОЕ УПРАВЛЕНИЕ ГЕОФИЗИЧЕСКИХ РАБОТ ‹ СКВАЖИНА: 11376 ПЛОЩАДЬ: АЛЬКЕЕВСКАЯ ДАТА ИССЛЕДОВАНИЯ: 18.08.04 . ЗАКАЗЧИК:ЦКРС "СУЛЕЕВСКИЙ" 3АМЁР ГК ДЛЯ ПРИВЯЗКИ К РАЗРЕЗУ ЗАМЕР ЛОКАТОРОМ МУФТ. \\БОЙ: 1683 м ТИН ПРИБОРА: ГДИ-5№23 СКВ.: 216 мм СКОРОСТЬ ЗАПИСИ : 400м/час КОНД.: 228 мм СЧЕТЧИК ГК: 2(40 60) КОНД.: 176 м КОЛ — 203 мм;146мм КОЛ: } (649 - 1541 м ‚ АЧАЛЬНИК ПАРТИИ: — №6 Тишкин ГАРШИЙ ГЕОЛОГ: % /Ибрагимова Т.М./ /Хасаншина Д.И./ | %“ /3/„› _ \' ‚ у о 1000 2000 3000 4000 5000 ` . Ё ] МГ я 8 20 — 24 к ГК (имп/мин) ЛМ (мВ) 0 200 40( ЭГ лА л'

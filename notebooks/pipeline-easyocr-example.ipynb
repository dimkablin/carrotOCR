# %%
# if you are not in IDE
import os

project_root = "/mnt/c/Users/dimka/PycharmProjects/TatneftIT_OCR"
os.chdir(project_root)

# %%
import mmcv
import src.features.build_features as pp
from src.visualization.visualize import *

# %%
url0 = 'data/raw/example.jpg'
image0 = mmcv.imread(url0)

def preprocessing(image):
    image = mmcv.bgr2gray(image)
    image = pp.threshold(image, thresh=120)
    image = mmcv.gray2rgb(image)

    return image

image0 = preprocessing(image0)

show(image0)

# %%
from src.models.ocr import OCRModelFactory

model = OCRModelFactory.create("easyocr")
# Out:
# Using CPU. Note: This module is much faster with a GPU.

# %%
outputs = model([image0])

# %%
result2show(image0, outputs[0])

# %%
' '.join(outputs[0]['rec_texts'])
# Out:
# "Чра &; 30 Военная Коллегия С П ₽ А В К А Верховного Суда = Союза ССР Дело ло обвинению ГОГОЗИНА Михаила Давидовича ле ОТ Военной Коллегией 21 сентября ховного Суда ресс '2ен0 мая 1956 года. 195 3 4н-04393/56 Приговор Воевной Коллегии ОТ 5 декабря 1937 года 8 отношении РОГОЗИНА М Д: ДО вновь Москва уд Воровского; 13, открывшимся обстоятельствам отменен и дело за отст ствием состава преступления прекращено; %сбз в М Д реабилитирован посмертно . Вёрха НАЧАЛЫНИК СЕКРЕТАРИАТА #ОшЕги ВЕРХОВНОГО СУц Юсвл ОдпОлковник кСТИ /ПОЛЮнкиЮ/ Вер- гия: 2 чънна"

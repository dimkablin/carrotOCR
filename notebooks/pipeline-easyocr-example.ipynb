# %%
# if you are not in IDE
import os

project_root = "/mnt/c/Users/dimka/PycharmProjects/TatneftIT_OCR"
os.chdir(project_root)

# %%
import mmcv
import src.features.build_features as pp
from src.visualization.visualize import *

# %%
url0 = 'data/raw/example1.jpg'
image0 = mmcv.imread(url0)

def preprocessing(image):
    image = mmcv.bgr2gray(image)
    image = pp.threshold(image, thresh=120)
    image = mmcv.gray2rgb(image)

    return image

#image0 = preprocessing(image0)

show(image0)

# %%
from src.models.ocr import OCRModelFactory

model = OCRModelFactory.create("easyocr")
# Out:
# Using CPU. Note: This module is much faster with a GPU.

# %%
outputs = model([image0])

# %%
result2show(image0, outputs[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 result2show(image0, outputs[0])
#
# File /mnt/c/Users/dimka/PycharmProjects/TatneftIT_OCR/src/visualization/visualize.py:68, in result2show(image, result, cmap)
#      64     axis[0].add_patch(rect0)
#      65     axis[1].add_patch(rect1)
#      66     axis[1].text(x_coord[0],
#      67                  np.mean(y_coord),
# ---> 68                  rec_texts.replace('$', r=r'\$'),
#      69                  color='black',
#      70                  fontsize=7,
#      71                  va='center')
#      73 plt.tight_layout()
#      74 plt.show()
#
# TypeError: str.replace() takes no keyword arguments

# %%
' '.join(outputs[0]['rec_texts'])
